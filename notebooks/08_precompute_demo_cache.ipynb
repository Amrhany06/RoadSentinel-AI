# %% [markdown]
# # 08 — Precompute Demo Cache (Demo-Safe Architecture)
# **RoadSentinel AI** — Runs pipeline offline once across curated demo clips.
# Pre-renders annotated videos and caches JSON telemetry so the live app has zero latency.

# %%
import os, sys
sys.path.insert(0, '..')
from scripts.precompute_all import run_precompute

# %% [markdown]
# ## 1. Execute Offline Batch Precomputation

# %%
run_precompute()
print("All demo clips and telemetry results precomputed in demo/precomputed/!")
